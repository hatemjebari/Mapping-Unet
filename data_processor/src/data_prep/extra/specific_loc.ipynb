# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("data_Resifi.csv")
data.set_index("Unnamed: 0",inplace = True)

# %%
data.head()
# Out:
#                      mslp(hPa)   t2(C)  td2(C)  wind_speed(m/s)  \
# Unnamed: 0
# 2008-01-01 00:00:00   1012.751  14.887   2.606            2.669
# 2008-01-01 01:00:00   1012.917  14.429   3.363            2.667
# 2008-01-01 02:00:00   1012.966  14.580   3.778            3.341
# 2008-01-01 03:00:00   1013.247  14.390   3.507            3.141
# 2008-01-01 04:00:00   1013.083  14.388   3.869            3.607
#
#                      wind_dir(Deg)   rh(%)  GHI(W/m2)  SWDIR(W/m2)  \
# Unnamed: 0
# 2008-01-01 00:00:00        105.078  43.686        0.0          0.0
# 2008-01-01 01:00:00        106.699  47.442        0.0          0.0
# 2008-01-01 02:00:00        112.426  48.357        0.0          0.0
# 2008-01-01 03:00:00        102.371  48.125        0.0          0.0
# 2008-01-01 04:00:00        111.300  49.295        0.0          0.0
#
#                      SWDNI(W/m2)  SWDIF(W/m2)  rain(mm)    AOD
# Unnamed: 0
# 2008-01-01 00:00:00          0.0          0.0       0.0  0.098
# ...

# %%
data.corr()
# Out:
#                  mslp(hPa)     t2(C)    td2(C)  wind_speed(m/s)  \
# mslp(hPa)         1.000000 -0.754257 -0.658666         0.149723
# t2(C)            -0.754257  1.000000  0.508091         0.050284
# td2(C)           -0.658666  0.508091  1.000000        -0.336033
# wind_speed(m/s)   0.149723  0.050284 -0.336033         1.000000
# wind_dir(Deg)    -0.206046  0.302226  0.360664        -0.116502
# rh(%)            -0.093597 -0.266858  0.667313        -0.412789
# GHI(W/m2)        -0.130054  0.449254  0.080313         0.200448
# SWDIR(W/m2)      -0.147830  0.446984  0.086690         0.205538
# SWDNI(W/m2)      -0.098035  0.415188  0.061091         0.183962
# SWDIF(W/m2)      -0.026196  0.295884  0.031016         0.112335
# rain(mm)          0.004320 -0.038924  0.029379         0.017310
# AOD              -0.743134  0.742217  0.569046        -0.140215
#
#                  wind_dir(Deg)     rh(%)  GHI(W/m2)  SWDIR(W/m2)  SWDNI(W/m2)  \
# ...
